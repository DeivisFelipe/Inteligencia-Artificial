# %%
# Esse programa serve para fazer o scraping de dados de Virus e criar um ontologia em OWL
# Autor: Deivis Felipe Guerreiro Fagundes
# Data: 21/05/2023

# %%
# Faz o import das bibliotecas
# Selenium é uma biblioteca para fazer o scraping de dados
# Pandas é uma biblioteca para manipular os dados
# Time é uma biblioteca para fazer o programa esperar um tempo
# BeautifulSoup é uma biblioteca para fazer o scraping de dados
# OWLReady2 é uma biblioteca para criar ontologias em OWL
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd
import time
from bs4 import BeautifulSoup
import os
# biblioteca para criar ontologias usando rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace

# %%
# Captura a pagina html do site
driver_path = './chromedriver.exe'

service = Service(driver_path)

# inicializa o driver do Selenium que esta dentro da pasta
driver = webdriver.Chrome(service=service)

# acessa o site que contem os dados
driver.get('https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=Undef&name=Viruses&lvl=5&srchmode=1&keep=1&unlock')

time.sleep(1)

# Clica no checkbox com o value "host"
driver.find_element('css selector', "input[value='host']").click()

# Clica no checkbox com o value "viral_host"
driver.find_element('css selector', "input[value='viral_host']").click()

# Clica no botão input com o value "Go"
driver.find_element('css selector', "input[value='Go']").click()

# espera 5 segundos para carregar a pagina
time.sleep(5)

# pega o html da pagina
html = driver.page_source

# fecha o driver
driver.close()

# %%
# Faz o scraping dos dados
# cria uma strutura de dados onde cada item pode ter um nome, um link e uma lista de filhos, ou ser virus
class Item:
    def __init__(self, name, link, children, isVirus, hosts, viral_hosts):
        self.name = name
        self.link = link
        self.children = children
        self.isVirus = isVirus
        self.hosts = hosts
        self.viral_hosts = viral_hosts

    # retorna uma string com os dados do item
    def __str__(self):
        return f'Item: {self.name}, Link: {self.link}, isVirus: {self.isVirus}'

# cria uma lista de itens
items = []

quantidade = 0

# Pega o primeiro UL dentro da tag form
ul = BeautifulSoup(html, 'html.parser').find('form').find('ul')

def CriaItem(li, parent):
    # atualiza a quantidade de itens
    global quantidade
    quantidade += 1

    # pega o nome do item
    name = li.find('a').text

    # pega o link do item
    link = li.find('a')['href']

    # pega os filhos do item
    children = []

    # verifica se o item é um virus
    isVirus = False

    # verifica se o item é um virus, se o tipo do li for 'square', então é um virus
    if li['type'] == 'square':
        isVirus = True

    # Pega os hosts do item da tag small dentro do li, onde o texto começa com " Host=", exemplo " Host=plants"
    # apenas se tiver
    hosts = []
    if li.find('small', text=lambda t: t and t.startswith(' Host=')) != None:
        hosts = li.find('small', text=lambda t: t and t.startswith(' Host=')).text.replace(' Host=', '').split('|')

    # Pega os viral hosts do item da tag small dentro do li, onde o texto começa com " Viral Host=", exemplo " Viral Host=plants"
    # apenas se tiver
    viral_hosts = []
    if li.find('small', text=lambda t: t and t.startswith(' Viral Host=')) != None:
        viral_hosts = li.find('small', text=lambda t: t and t.startswith(' Viral Host=')).text.replace(' Viral Host=', '').split('|')


    # cria um item com os dados
    item = Item(name, link, children, isVirus, hosts, viral_hosts)

    # verifica se o item tem um pai
    if parent != None:
        # adiciona o item na lista de filhos do pai
        parent.children.append(item)
    else :
        # adiciona o item na lista de itens
        items.append(item)

    # verifica se o item tem filhos
    if li.find('ul') != None:

        # pega o primeiro UL dentro da tag form
        ul = li.find('ul')

        # pega todos os LI dentro do UL, só filhos diretos
        lis = ul.find_all('li', recursive=False)

        # para cada LI dentro do UL
        for li in lis:

            # chama a função novamente
            CriaItem(li, item)

# para cada LI dentro do UL
for li in ul.find_all('li', recursive=False):
    # chama a função para criar o item
    CriaItem(li, None)
# Out:
# C:\Users\guerr\AppData\Local\Temp\ipykernel_14408\3652346479.py:48: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if li.find('small', text=lambda t: t and t.startswith(' Host=')) != None:
# C:\Users\guerr\AppData\Local\Temp\ipykernel_14408\3652346479.py:49: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   hosts = li.find('small', text=lambda t: t and t.startswith(' Host=')).text.replace(' Host=', '').split('|')
# C:\Users\guerr\AppData\Local\Temp\ipykernel_14408\3652346479.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if li.find('small', text=lambda t: t and t.startswith(' Viral Host=')) != None:
# C:\Users\guerr\AppData\Local\Temp\ipykernel_14408\3652346479.py:55: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   viral_hosts = li.find('small', text=lambda t: t and t.startswith(' Viral Host=')).text.replace(' Viral Host=', '').split('|')

# %%
# Printa os itens como se fosse uma arvore
def PrintaItens(item, level):
    # printa o nome do item
    print(f'{" " * level}{item.name}')

    # verifica se o item tem filhos
    if len(item.children) > 0:
        # para cada filho do item
        for child in item.children:
            # chama a função novamente
            PrintaItens(child, level + 1)

# printa só o primeiro ramo da arvore
PrintaItens(items[0], 0)
# Out:
# Viruses
#  Adnaviria
#   Zilligvirae
#    Taleaviricota
#     Tokiviricetes
#      Ligamenvirales
#      Primavirales
#  Alphasatellitidae
#   Coconut foliar decay alphasatellite
#   Geminialphasatellitinae
#    Ageyesisatellite
#     Ageratum yellow vein Singapore alphasatellite
#    Clecrusatellite
#     Ash gourd yellow vein mosaic alphasatellite
#     Capsicum India alphasatellite
#      Begomovirus-associated alphasatellite sp.
#     Cleome leaf crumple alphasatellite
#     Croton yellow vein mosaic alphasatellite
#     Euphorbia yellow mosaic alphasatellite
#      Euphorbia yellow mosaic virus associated DNA 1
#     Melon chlorotic mosaic alphasatellite
#     Tomato leaf curl Anand alphasatellite
#     Tomato leaf curl New Delhi alphasatellite
#     Tomato leaf curl Virudhunagar alphasatellite
#     Tomato yellow spot alphasatellite
#     Tomato yellow spot alphasatellite 2
#     Whitefly associated Guatemala alphasatellite 2
#     Whitefly associated Puerto Rico alphasatellite 1
#    Colecusatellite
#     Ageratum enation alphasatellite
#     Ageratum yellow vein alphasatellite
#     Ageratum yellow vein China alphasatellite
#     Ageratum yellow vein India alphasatellite
#     Bhendi yellow vein alphasatellite
#     Cassava mosaic Madagascar alphasatellite
#     Chilli leaf curl alphasatellite
#     Cotton leaf curl Gezira alphasatellite
#      Cotton leaf curl Gezira alphasatellite-[Okra/Jordan-J10-36]
#      Cotton leaf curl Gezira alphasatellite-[Okra/Jordan-J2-5]
#      Cotton leaf curl Gezira alphasatellite-[Okra/Jordan-J3-35]
#     Cotton leaf curl Lucknow alphasatellite
#     Cotton leaf curl Multan alphasatellite
#     Gossypium darwinii symptomless alphasatellite
#      Cotton leaf curl alphasatellite
#      Xanthium symptomless alphasatellite
#     Malvastrum yellow mosaic alphasatellite
#     Malvastrum yellow mosaic Cameroon alphasatellite
#     Pedilanthus leaf curl alphasatellite
#     Sida leaf curl alphasatellite 2
#      Sida leaf curl alphasatellite
#     Sida yellow vein Vietnam alphasatellite
#     Sunflower leaf curl Karnataka alphasatellite
#     Synedrella leaf curl alphasatellite
#     Tobacco curly shoot alphasatellite
#      Tobacco leaf curl Yunnan virus associated DNA 1
#     Tomato leaf curl Cameroon alphasatellite
#      Tomato leaf curl Cameroon alphasatellite [CM:AGLD1:Ag:09]
#      Tomato leaf curl Cameroon alphasatellite [CM:OMHD3:Ok:09]
#      Tomato leaf curl Cameroon alphasatellite [CM:TOS2D1:To:09]
#      Tomato leaf curl Cameroon alphasatellite [CM:TOS2D2:To:09]
#      Tomato leaf curl Cameroon alphasatellite [CM:TOS2D3:To:09]
#     Tomato leaf curl Pakistan alphasatellite
#      Tomato leaf curl alphasatellite
#      Tomato leaf curl Pakistan defective alphasatellite
#     Tomato yellow leaf curl China alphasatellite
#     Tomato yellow leaf curl Thailand alphasatellite
#     Tomato yellow leaf curl Yunnan alphasatellite
#    Draflysatellite
#     Dragonfly associated alphasatellite
#    Gosmusatellite
#     Cotton leaf curl Cameroon alphasatellite
#      Cotton leaf curl Gezira alphasatellite 3
#     Eclipta yellow vein alphasatellite
#     Gossypium mustelinum symptomless alphasatellite
#     Hollyhock yellow vein alphasatellite
#     Mesta yellow vein mosaic alphasatellite
#     Okra enation leaf curl alphasatellite
#     Okra yellow crinkle Cameroon alphasatellite
#      Okra yellow crinkle Cameroon alphasatellite [CM:Lys1sp2:09]
#      Okra yellow crinkle Cameroon alphasatellite [CM:Lys1sp3:09]
#      Okra yellow crinkle Cameroon alphasatellite [CM:Lys1sp4:09]
#      Okra yellow crinkle Cameroon alphasatellite [CM:Njo5sp2:09]
#      Okra yellow crinkle Cameroon alphasatellite [CM:Njo5sp3:09]
#     Vernonia yellow vein Fujian alphasatellite
#    Somasatellite
#     Sorghum mastrevirus associated alphasatellite
#    Whiflysatellite
#     Whitefly associated Guatemala alphasatellite 1
#    unclassified Begomovirus-associated alphasatellites
#     Ageratum conyzoides associated symptomless alphasatellite
#     Ageratum conyzoides symptomless alphasatellite
#     Ageratum enation virus associated DNA 1
#     Ageratum leaf curl Cameroon alphasatellite
#      Ageratum leaf curl Cameroon alphasatellite [CM:AGLD3:Ag:09]
#      Ageratum leaf curl Cameroon alphasatellite [CM:ODL1D1:Ok:09]
#      Ageratum leaf curl Cameroon alphasatellite [CM:ODL1D2:Ok:09]
#      Ageratum leaf curl Cameroon alphasatellite [CM:OMHD2:Ok:09]
#     Ageratum yellow leaf curl Pakistan alphasatellite
#     Ageratum yellow vein Pakistan alphasatellite
#     Alphasatellite 1
#     Alphasatellite 2
#     Alphasatellite 3
#     Alternanthera yellow vein alphasatellite
#     Bendhi Yellow Vein Mosaic/Mesta Yellow Vein Mosaic alphasatellite
#     Bhendi yellow vein mosaic alphasatellite
#     Bhendi yellow vein mosaic virus-associated alphasatellite
#     Bhindi yellow vein alphasatellite
#    Pea necrotic yellow dwarf alphasatellite 6
#    Pea necrotic yellow dwarf alphasatellite 7
#    Pittosporum tobira alphasatellite
#    Pittosporum tobira alphasatellite 1
#    Pittosporum tobira alphasatellite 2
#    Pittosporum tobira alphasatellite 3
#    Alphasatellitidae sp.
#  Ampullaviridae
#   Ampullavirus
#   Bottigliavirus
#    Bottigliavirus ABV
#     Acidianus bottle-shaped virus
#      Acidianus bottle-shaped virus (isolate Pozzuoli)
#    Bottigliavirus ABV2
#     Acidianus bottle-shaped virus 2 strain ABV2
#    Bottigliavirus ABV3
#     Acidianus bottle-shaped virus 3 strain ABV3
#  Anelloviridae
#   Aleptorquevirus
#    Torque teno leprid virus 1
#     Lepus torque teno virus 1
#   Alphatorquevirus
#    Alphatorquevirus cerco6
#     Torque teno virus 26
#    Alphatorquevirus cerco7
#     Torque teno virus 25
#    Alphatorquevirus homin1
#     Torque teno virus 1
#      Torque teno virus 1 (isolate TA278)
#    Alphatorquevirus homin10
#     Torque teno virus 10
#    Alphatorquevirus homin13
#     Torque teno virus 13
#    Alphatorquevirus homin14
#     Torque teno virus 14
#    Alphatorquevirus homin15
#     Torque teno virus 15
#    Alphatorquevirus homin17
#     Torque teno virus 17
#    Alphatorquevirus homin18
#     Torque teno virus 18
#    Alphatorquevirus homin19
#     Torque teno virus 19
#    Alphatorquevirus homin2
#     Torque teno virus 2
#    Alphatorquevirus homin20
#     Torque teno virus 20
#    Alphatorquevirus homin21
#     Torque teno virus 21
#    Alphatorquevirus homin24
#     Torque teno virus 24
#    Alphatorquevirus homin29
#     Torque teno virus 29
#    Alphatorquevirus homin3
#     Torque teno virus 3
#    Alphatorquevirus homin4
#     Torque teno virus 4
#    Alphatorquevirus homin5
#     Torque teno virus 5
#    Alphatorquevirus homin6
#     Torque teno virus 6
#    Alphatorquevirus homin7
#     Torque teno virus 7
#    Alphatorquevirus homin9
#     Torque teno virus 9
#    Torque teno chlorocebus virus 1
#     Simian torque teno virus 30
#    Torque teno chlorocebus virus 2
#     Simian torque teno virus 34
#    Torque teno chlorocebus virus 3
#     Simian torque teno virus 31
#    Torque teno chlorocebus virus 5
#     Simian torque teno virus 32
#    Torque teno virus 11
#    Torque teno virus 12
#    Torque teno virus 16
#    Torque teno virus 22
#    Torque teno virus 23
#    Torque teno virus 27
#    Torque teno virus 28
#    Torque teno virus 8
#    unclassified Alphatorquevirus
#     Cerdocyon thous torque teno virus 1
#     Cerdocyon thous torque teno virus 2
#     Cerdocyon thous torque teno virus 3
#     Cerdocyon thous torque teno virus 4
#     Lycalopex gymnocercus torque teno virus 1
#     Lycalopex gymnocercus torque teno virus 2
#     Simian torque teno virus
#     Simian torque teno virus 33
#     Alphatorquevirus sp.
#   Betatorquevirus
#    Betatorquevirus homini1
#     Torque teno mini virus 1
#      Torque teno mini virus 1 (isolate TLMV-CBD279)
#    Betatorquevirus homini10
#     Torque teno mini virus 10
#    Betatorquevirus homini11
#     Torque teno mini virus 11
#    Betatorquevirus homini12
#     Torque teno mini virus 12
#    Betatorquevirus homini2
#     Torque teno mini virus 2
#      Small anellovirus KR-BD-0092
#      Small anellovirus KR-BD-0096
#      Small anellovirus KR-BD-0105
#      Small anellovirus KR-BD-0115
#      Small anellovirus KR-BD-0130
#      Small anellovirus KR-BD-0135
#      Small anellovirus KR-BD-0147
#      Small anellovirus KR-BD-0157
#      Small anellovirus KR-BD-0161
#      Small anellovirus KR-BD-0164
#      Small anellovirus KR-BD-0188
#      Small anellovirus KR-BD-0191
#      Small anellovirus KR-BD-0224
#      Small anellovirus KR-BD-0226
#      Small anellovirus KR-BD-0232
#      Small anellovirus KR-BD-0241
#      Small anellovirus KR-BD-0250
#      Small anellovirus KR-BD-0265
#      Small anellovirus KR-BD-0275
#      Small anellovirus KR-BD-0277
#      Small anellovirus KR-BD-0282
#      Small anellovirus KR-PN-0002P
#      Small anellovirus KR-PN-0003P
#      Small anellovirus KR-PN-0018P
#     Small anellovirus KR-CT-0017
#     Small anellovirus KR-CT-0019
#     Small anellovirus KR-CT-0031
#     Small anellovirus KR-CT-0040
#     Small anellovirus KR-CT-0048
#     Small anellovirus KR-EB-0162
#     Small anellovirus KR-HB-0140
#     Small anellovirus KR-HB-0185
#     Small anellovirus KR-HB-0210
#     Small anellovirus KR-HC-0005
#     Small anellovirus KR-HC-0023
#     Small anellovirus KR-HC-0042
#     Small anellovirus KR-KD-0034
#     Small anellovirus KR-KD-0035
#     Small anellovirus KR-PN-0002
#     Small anellovirus KR-PN-0003
#     Small anellovirus KR-PN-0018
#     Small anellovirus KR-PN-0021
#     Small anellovirus KR-PN-0029
#     Small anellovirus KR-UH-0237
#     Small anellovirus RIC-VIPI
#     Small anellovirus TER-VIPI
#    Tick-associated anellovirus 1
#    Tick-associated anellovirus 10
#    Tick-associated anellovirus 2
#    Tick-associated anellovirus 3
#    Tick-associated anellovirus 4
#    Tick-associated anellovirus 5
#    Tick-associated anellovirus 6
#    Tick-associated anellovirus 7
#    Tick-associated anellovirus 8
#    Tick-associated anellovirus 9
#    ticpantry virus 1
#    ticpantry virus 2
#    Torque teno arctocephalus australis virus
#    Torque teno arctocephalus australis virus 1
#    Torque teno arctocephalus australis virus 2
#    Torque teno arctocephalus australis virus 3
#    Torque teno arctocephalus australis virus 4
#    Torque teno arctocephalus australis virus 5
#    Torque teno arctocephalus australis virus 6
#    Torque teno calomys tener virus
#    Torque teno carollia perspicillata virus
#    Torque teno desmodus rotundus virus
#    Torque teno like mini virus Isfahan
#    Torque teno midi virus
#    Torque teno mustelid virus 2
#    Torque teno neovison virus
#    Torque teno Tadarida brasiliensis virus 2
#    Torque teno Tadarida brasiliensis virus 3
#    Torque teno virus
#     Paguma larvata torque teno virus
#     Pigeon torque teno virus
#     Sentinel Virus I
#     Torque teno virus Chimpanzee/Japan/Pt-TTV6/2000
#     Torque teno virus cya/2019
#     Torque teno virus cyb/2019
#     Torque teno virus cyc/2019
#     Torque teno virus Japanese macaque/Japan/Mf-TTV9/2000
#     Torque teno virus VT416
#     TT virus cya/2019
#     TT virus cyb/2019
#     TT virus cyc/2019
#     TT virus genotype 6
#     TT virus group 1
#      Woesvirus
#      Woodruffvirus
#      Wumpquatrovirus
#      Wumptrevirus
#      Xiamenvirus
#      Xipdecavirus
#      Xuquatrovirus
#      Yangvirus
#      Yeceytrevirus
#      Yokohamavirus
#      Yoloswagvirus
#      Yongloolinvirus
#      Yvonnevirus
#      Zetavirus
#      Zierdtviridae
#      Zitchvirus
#      Zobellviridae
#      unclassified Caudoviricetes
#      environmental samples
#    unclassified Heunggongvirae
#     Salmonella phage NCTh5
#     Salmonella phage PST-H4
#     Heunggongvirae sp.
#  Finnlakeviridae
#   Finnlakevirus
#    Finnlakevirus FLiP
#     Flavobacterium phage FLiP
#  Fuselloviridae
#   Alphafusellovirus
#    Sulfolobus spindle-shaped virus 1
#    Sulfolobus spindle-shaped virus 2
#    Sulfolobus spindle-shaped virus 4
#    Sulfolobus spindle-shaped virus 5
#    Sulfolobus spindle-shaped virus 7
#    Sulfolobus spindle-shaped virus 8
#     Sulfolobus virus Ragged Hills
#    Sulfolobus spindle-shaped virus 9
#     Sulfolobus virus Kamchatka 1
#    unidentified Fusellovirus
#    unclassified Alphafusellovirus
#     Sulfolobus spindle-shaped virus
#     Sulfolobus spindle-shaped virus 3
#     Sulfolobus spindle-shaped virus Lassen
#   Betafusellovirus
#    Acidianus spindle-shaped virus 1
#    Sulfolobus spindle-shaped virus 6
#    unclassified Betafusellovirus
#     Sulfolobus spindle-shaped virus SSV19
#   unclassified Fuselloviridae
#    Lokiarchaeota virus WyrdV1
#    Sulfolobales Mexican fusellovirus 1
#    Sulfolobus super-elliptical virus
#  Globuloviridae
#   Alphaglobulovirus
#    Alphaglobulovirus PSV
#     Pyrobaculum spherical virus
#      Pyrobaculum spherical virus (isolate Yellowstone)
#    Alphaglobulovirus PSV2
#     Pyrobaculum spherical virus 2
#    Alphaglobulovirus TSPV1
#     Thermoproteus spherical piliferous virus 1
#    Alphaglobulovirus TTSV1
#     Thermoproteus tenax spherical virus 1
#   Globulovirus
#  Guttaviridae
#   Alphaguttavirus
#    Sulfolobus newzealandicus droplet-shaped virus
#   Betaguttavirus
#    Aeropyrum pernix ovoid virus 1
#  Halspiviridae
#   Salterprovirus
#    Salterprovirus His1
#     His 1 virus
#     His1 virus (isolate Victoria)
#    unclassified Salterprovirus
#  Monodnaviria
#   Loebvirae
#    Hofneiviricota
#     Faserviricetes
#      Tubulavirales
#   Sangervirae
#    Phixviricota
#     Malgrandaviricetes
#      Petitvirales
#   Shotokuvirae
#    Cossaviricota
#     Mouviricetes
#      Polivirales
#     Papovaviricetes
#      Sepolyvirales
#      Zurhausenvirales
#      unclassified Papovaviricetes
#     Quintoviricetes
#      Piccovirales
#    Cressdnaviricota
#     Arfiviricetes
#      Baphyvirales
#      Cirlivirales
#      Cremevirales
#      Mulpavirales
#      Recrevirales
#      Rivendellvirales
#      Rohanvirales
#     Repensiviricetes
#      Geplafuvirales
#     unclassified Cressdnaviricota
#      Amazon milk frog associated circular DNA virus
#      Antarctic virus 1_I_CPGEORsw001Ad
#      Antarctic virus 1_I_CPGEORsw002Ad
#      Antarctic virus 1_II_CPGEORsw003Ad
#      Chicken proventriculitis-associated circular virus 7
#      Chicken proventriculitis-associated circular virus 8
#      Chicken proventriculitis-associated circular virus 9
#      Chifec virus UA13_101
#      Chifec virus UA13_110
#      Chifec virus UA13_111
#      Chifec virus UA13_115
#      Chifec virus UA13_119
#      Chifec virus UA13_122
#      Chifec virus UA13_133
#      Chifec virus UA13_150
#      Chifec virus UA13_58
#      Chifec virus UA13_72
#      Chifec virus UA13_77
#      Clinch circular virus 1
#      Clinch circular virus 2
#      Clinch CRESS virus 1
#      CRESS viruses
#      Delphin virus 1
#      Delphin virus 2
#      Delphin virus 3
#      Dipodfec virus RodF1_112
#      Dipodfec virus RodF1_131
#      Dipodfec virus RodF1_132
#      Dipodfec virus UA04Rod_2041
#      Dipodfec virus UA04Rod_4537
#      Dipodfec virus UA04Rod_5684
#      Dipodfec virus UA04Rod_5913
#      Dipodfec virus UA06Rod_119
#      Dipodfec virus UA06Rod_92
#      Dipodfec virus UA23Rod_1661
#      Dipodfec virus UA23Rod_4953
#      Dipodfec virus UA23Rod_5718
#      Dipodfec virus UA23Rod_6578
#      Entamoeba-associated CRESS DNA virus 1
#      Feline stool-associated circular virus
#      Giant panda associated circular DNA virus
#      Giant panda feces-associated circular DNA virus
#      Giardia-associated CRESS DNA virus 2
#      Giardia-associated CRESS DNA virus 3
#      Lutraria rhynchaena circular ssDNA virus
#      Marmot associated feces circular DNA molecule 1
#      Marmot associated feces circular DNA molecule 2
#      Marmot associated feces circular DNA molecule 3
#      Marmot associated feces circular DNA molecule 4
#      Marmot associated feces virus 1
#      Marmot associated feces virus 2
#      Marmot associated feces virus 3
#      Marmot associated feces virus 5
#      Marmot associated feces virus 6
#      Molossus molossus associated CRESS DNA virus
#      Mute swan feces associated circular virus 1
#      Mute swan feces associated circular virus 10
#      Mute swan feces associated circular virus 11
#      Mute swan feces associated circular virus 12
#      Mute swan feces associated circular virus 13
#      Mute swan feces associated circular virus 14
#      Mute swan feces associated circular virus 15
#      Mute swan feces associated circular virus 16
#      Mute swan feces associated circular virus 17
#      Mute swan feces associated circular virus 2
#      Mute swan feces associated circular virus 3
#      Mute swan feces associated circular virus 4
#      Mute swan feces associated circular virus 5
#      Mute swan feces associated circular virus 6
#      Mute swan feces associated circular virus 7
#      Mute swan feces associated circular virus 8
#      Mute swan feces associated circular virus 9
#      Myodefec virus RodL3_773
#      Myodefec virus RodL3_976
#      Peromfec virus RodF5_42
# ...
#    Marine virus AFVG_250N00479
#    Marine virus AFVG_250N00480
#    Marine virus AFVG_250N00482
#    Marine virus AFVG_250N00483
#    Marine virus AFVG_250N00484
#    Marine virus AFVG_250N00487
#    Marine virus AFVG_250N00488
#    Marine virus AFVG_250N00491
#    Marine virus AFVG_250N00492
#    Marine virus AFVG_250N00493
#    Marine virus AFVG_250N00495
#    Marine virus AFVG_250N00496
#    Marine virus AFVG_250N00498
#    Marine virus AFVG_250N00499
#    Marine virus AFVG_250N00502
#    Marine virus AFVG_250N00504
#    Marine virus AFVG_250N00505
#    Marine virus AFVG_250N00506
#    Marine virus AFVG_250N00507
#    Marine virus AFVG_250N00508
#    Marine virus AFVG_250N00509
#    Marine virus AFVG_250N00511
#    Marine virus AFVG_250N00512
#    Marine virus AFVG_250N00514
#    Marine virus AFVG_250N00515
#    Marine virus AFVG_250N00516
#    Marine virus AFVG_250N00518
#    Marine virus AFVG_250N00519
#    Marine virus AFVG_250N00521
#    Marine virus AFVG_250N00522
#    Marine virus AFVG_250N00527
#    Marine virus AFVG_250N00528
#    Marine virus AFVG_250N00529
#    Marine virus AFVG_250N00531
#    Marine virus AFVG_250N00535
#    Marine virus AFVG_250N00537
#    Marine virus AFVG_250N00542
#    Marine virus AFVG_250N00543
#    Marine virus AFVG_250N00544
#    Marine virus AFVG_250N00546
#    Marine virus AFVG_250N00549
#    Marine virus AFVG_250N00550
#    Marine virus AFVG_250N00554
#    Marine virus AFVG_250N00555
#    Marine virus AFVG_250N00556
#    Marine virus AFVG_250N00558
#    Marine virus AFVG_250N00559
#    Marine virus AFVG_250N00560
#    Marine virus AFVG_250N00561
#    Marine virus AFVG_250N00562
#    Marine virus AFVG_250N00564
#    Marine virus AFVG_250N00565
#    Marine virus AFVG_250N00566
#    Marine virus AFVG_250N00567
#    Marine virus AFVG_250N00569
#    Marine virus AFVG_250N00570
#    Marine virus AFVG_250N00571
#    Marine virus AFVG_250N00573
#    Marine virus AFVG_250N00575
#    Marine virus AFVG_250N00576
#    Marine virus AFVG_250N00579
#    Marine virus AFVG_250N00581
#    Marine virus AFVG_250N00582
#    Marine virus AFVG_250N00584
#    Marine virus AFVG_250N00585
#    Marine virus AFVG_250N00586
#    Marine virus AFVG_250N00588
#    Marine virus AFVG_250N00589
#    Marine virus AFVG_250N00591
#    Marine virus AFVG_250N00595
#    Marine virus AFVG_250N00596
#    Marine virus AFVG_250N00597
#    Marine virus AFVG_250N00598
#    Marine virus AFVG_250N00605
#    Marine virus AFVG_250N00609
#    Marine virus AFVG_250N00610
#    Marine virus AFVG_250N00612
#    Marine virus AFVG_250N00617
#    Marine virus AFVG_250N00621
#    Marine virus AFVG_250N00622
#    Marine virus AFVG_250N00625
#    Marine virus AFVG_250N00626
#    Marine virus AFVG_250N00629
#    Marine virus AFVG_250N00630
#    Marine virus AFVG_250N00631
#    Marine virus AFVG_250N00632
#    Marine virus AFVG_250N00637
#    Marine virus AFVG_250N00638
#    Marine virus AFVG_250N00639
#    Marine virus AFVG_250N00643
#    Marine virus AFVG_250N00644
#    Marine virus AFVG_250N00647
#    Marine virus AFVG_250N00649
#    Marine virus AFVG_250N00650
#    Marine virus AFVG_250N00652
#    Marine virus AFVG_250N00653
#    Marine virus AFVG_250N00656
#    Marine virus AFVG_250N00659
#    Marine virus AFVG_250N00661
#    Marine virus AFVG_250N00664
#    Marine virus AFVG_250N00667
#    Marine virus AFVG_250N00668
#    Marine virus AFVG_250N00670
#    Marine virus AFVG_250N00671
#    Marine virus AFVG_250N00678
#    Marine virus AFVG_250N00681
#    Marine virus AFVG_250N00682
#    Marine virus AFVG_250N00684
#    Marine virus AFVG_250N00686
#    Marine virus AFVG_250N00687
#    Marine virus AFVG_250N00692
#    Marine virus AFVG_250N00696
#    Marine virus AFVG_250N00698
#    Marine virus AFVG_250N00699
#    Marine virus AFVG_250N00700
#    Marine virus AFVG_250N00702
#    Marine virus AFVG_250N00705
#    Marine virus AFVG_250N00707
#    Marine virus AFVG_250N00708
#    Marine virus AFVG_250N00711
#    Marine virus AFVG_250N00712
#    Marine virus AFVG_250N00714
#    Marine virus AFVG_250N00716
#    Marine virus AFVG_250N00722
#    Marine virus AFVG_250N00723
#    Marine virus AFVG_250N00724
#    Marine virus AFVG_250N00725
#    Marine virus AFVG_250N00731
#    Marine virus AFVG_250N00732
#    Marine virus AFVG_250N00736
#    Marine virus AFVG_250N00739
#    Marine virus AFVG_250N00740
#    Marine virus AFVG_250N00745
#    Marine virus AFVG_250N00746
#    Marine virus AFVG_250N00747
#    Marine virus AFVG_250N00748
#    Marine virus AFVG_250N00749
#    Marine virus AFVG_250N00752
#    Marine virus AFVG_250N00753
#    Marine virus AFVG_250N00757
#    Marine virus AFVG_250N00760
#    Marine virus AFVG_250N00763
#    Marine virus AFVG_250N00765
#    Marine virus AFVG_250N00771
#    Marine virus AFVG_250N00772
#    Marine virus AFVG_250N00775
#    Marine virus AFVG_250N00778
#    Marine virus AFVG_250N00779
#    Marine virus AFVG_250N00784
#    Marine virus AFVG_250N00790
#    Marine virus AFVG_250N00791
#    Marine virus AFVG_250N00793
#    Marine virus AFVG_250N00798
#    Marine virus AFVG_250N00799
#    Marine virus AFVG_250N00801
#    Marine virus AFVG_250N00802
#    Marine virus AFVG_250N00806
#    Marine virus AFVG_250N00807
#    Marine virus AFVG_250N00808
#    Marine virus AFVG_250N00810
#    Marine virus AFVG_250N00814
#    Marine virus AFVG_250N00816
#    Marine virus AFVG_250N00820
#    Marine virus AFVG_250N00821
#    Marine virus AFVG_250N00823
#    Marine virus AFVG_250N00824
#    Marine virus AFVG_250N00826
#    Marine virus AFVG_250N00829
#    Marine virus AFVG_250N00833
#    Marine virus AFVG_250N00834
#    Marine virus AFVG_250N00835
#    Marine virus AFVG_250N00836
#    Marine virus AFVG_250N00838
#    Marine virus AFVG_250N00840
#    Marine virus AFVG_250N00841
#    Marine virus AFVG_250N00842
#    Marine virus AFVG_250N00851
#    Marine virus AFVG_250N00852
#    Marine virus AFVG_250N00856
#    Marine virus AFVG_250N00857
#    Marine virus AFVG_250N00858
#    Marine virus AFVG_250N00860
#    Marine virus AFVG_250N00862
#    Marine virus AFVG_250N00864
#    Marine virus AFVG_250N00871
#    Marine virus AFVG_250N00872
#    Marine virus AFVG_250N00873
#    Marine virus AFVG_250N00874
#    Marine virus AFVG_250N00876
#    Marine virus AFVG_250N00879
#    Marine virus AFVG_250N00881
#    Marine virus AFVG_250N00884
#    Marine virus AFVG_250N00885
#    Marine virus AFVG_250N00888
#    Marine virus AFVG_250N00889
#    Marine virus AFVG_250N00893
#    Marine virus AFVG_250N00896
#    Marine virus AFVG_250N00898
#    Marine virus AFVG_250N00899
#    Marine virus AFVG_250N00901
#    Marine virus AFVG_250N00902
#    Marine virus AFVG_250N00903
#    Marine virus AFVG_250N00906
#    Marine virus AFVG_250N00909
#    Marine virus AFVG_250N00910
#    Marine virus AFVG_250N00913
#    Marine virus AFVG_250N00915
#    Marine virus AFVG_250N00917
#    Marine virus AFVG_250N00918
#    Marine virus AFVG_250N00921
#    Marine virus AFVG_250N00923
#    Marine virus AFVG_250N00924
#    Marine virus AFVG_250N00927
#    Marine virus AFVG_250N00932
#    Marine virus AFVG_250N00935
#    Marine virus AFVG_250N00938
#    Marine virus AFVG_250N00944
#    Marine virus AFVG_250N00945
#    Marine virus AFVG_250N00948
#    Marine virus AFVG_250N00949
#    Marine virus AFVG_250N00950
#    Marine virus AFVG_250N00951
#    Marine virus AFVG_250N00953
#    Marine virus AFVG_250N00957
#    Marine virus AFVG_250N00958
#    Marine virus AFVG_250N00959
#    Marine virus AFVG_250N00960
#    Marine virus AFVG_250N00961
#    Marine virus AFVG_250N00964
#    Marine virus AFVG_250N00965
#    Marine virus AFVG_250N00966
#    Marine virus AFVG_250N00969
#    Marine virus AFVG_250N00971
#    Marine virus AFVG_250N00972
#    Marine virus AFVG_250N00974
#    Marine virus AFVG_250N00978
#    Marine virus AFVG_250N00981
#    Marine virus AFVG_250N00982
#    Marine virus AFVG_250N00983
#    Marine virus AFVG_250N00984
#    Marine virus AFVG_250N00986
#    Marine virus AFVG_250N00987
#    Marine virus AFVG_250N00988
#    Marine virus AFVG_250N00992
#    Marine virus AFVG_250N00995
#    Marine virus AFVG_250N00998
#    Marine virus AFVG_250N00999
#    Marine virus AFVG_250N01003
#    Marine virus AFVG_250N01005
#    Marine virus AFVG_250N01007
#    Marine virus AFVG_250N01010
#    Marine virus AFVG_250N01013
#    Marine virus AFVG_250N01016
#    Marine virus AFVG_250N01018
#    Marine virus AFVG_250N01019
#    Marine virus AFVG_250N01021
#    Marine virus AFVG_250N01026
#    Marine virus AFVG_250N01028
#    Marine virus AFVG_250N01030
#    Marine virus AFVG_250N01031
#    Marine virus AFVG_250N01033
#    Marine virus AFVG_250N01036
#    Marine virus AFVG_250N01037
#    Marine virus AFVG_250N01039
#    Marine virus AFVG_250N01040
#    Marine virus AFVG_250N01045
#    Marine virus AFVG_250N01050
#    Marine virus AFVG_250N01051
#    Marine virus AFVG_250N01056
#    Marine virus AFVG_250N01058
#    Marine virus AFVG_250N01060
#    Marine virus AFVG_250N01062
#    Marine virus AFVG_250N01065
#    Marine virus AFVG_250N01067
#    Marine virus AFVG_250N01069
#    Marine virus AFVG_250N01071
#    Marine virus AFVG_250N01072
#    Marine virus AFVG_250N01074
#    Marine virus AFVG_250N01080
#    Marine virus AFVG_250N01083
#    Marine virus AFVG_250N01085
#    Marine virus AFVG_250N01087
#    Marine virus AFVG_250N01091
#    Marine virus AFVG_250N01092
#    Marine virus AFVG_250N01093
#    Marine virus AFVG_250N01095
#    Marine virus AFVG_250N01096
#    Marine virus AFVG_250N01097
#    Marine virus AFVG_250N01098
#    Marine virus AFVG_250N01099
#    Marine virus AFVG_250N01100
#    Marine virus AFVG_250N01102
#    Marine virus AFVG_250N01103
#    Marine virus AFVG_250N01105
#    Marine virus AFVG_250N01106
#    Marine virus AFVG_250N01107
#    Marine virus AFVG_250N01108
#    Marine virus AFVG_250N01110
#    Marine virus AFVG_250N01112
#    Marine virus AFVG_250N01113
#    Marine virus AFVG_250N01116
#    Marine virus AFVG_250N01119
#    Marine virus AFVG_250N01121
#    Marine virus AFVG_250N01122
#    Marine virus AFVG_250N01124
#    Marine virus AFVG_250N01125
#    Marine virus AFVG_250N01126
#    Marine virus AFVG_250N01129
#    Marine virus AFVG_250N01131
#    Marine virus AFVG_250N01132
#    Marine virus AFVG_250N01138
#    Marine virus AFVG_250N01139
#    Marine virus AFVG_250N01140
#    Marine virus AFVG_250N01141
#    Marine virus AFVG_250N01142
#    Marine virus AFVG_250N01143
#    Marine virus AFVG_250N01144
#    Marine virus AFVG_250N01145
#    Marine virus AFVG_250N01146
#    Marine virus AFVG_250N01147
#    Marine virus AFVG_250N01148
#    Marine virus AFVG_250N01149
#    Marine virus AFVG_250N01150
#    Marine virus AFVG_250N01152
#    Marine virus AFVG_250N01155
#    Marine virus AFVG_250N01156
#    Marine virus AFVG_250N01158
#    Marine virus AFVG_250N01159
#    Marine virus AFVG_250N01162
#    Marine virus AFVG_250N01166
#    Marine virus AFVG_250N01168
#    Marine virus AFVG_250N01169
#    Marine virus AFVG_250N01170
#    Marine virus AFVG_250N01172
#    Marine virus AFVG_250N01174
#    Marine virus AFVG_250N01176
#    Marine virus AFVG_250N01180
#    Marine virus AFVG_250N01183
#    Marine virus AFVG_250N01185
#    Marine virus AFVG_250N01186
#    Marine virus AFVG_250N01188
#    Marine virus AFVG_250N01189
#    Marine virus AFVG_250N01190
#    Marine virus AFVG_250N01191
#    Marine virus AFVG_250N01194
#    Marine virus AFVG_250N01195
#    Marine virus AFVG_250N01196
#    Marine virus AFVG_250N01197
#    Marine virus AFVG_250N01198
#    Marine virus AFVG_250N01199
#    Marine virus AFVG_250N01201
#    Marine virus AFVG_250N01202
#    Marine virus AFVG_250N01205
#    Marine virus AFVG_250N01208
#    Marine virus AFVG_250N01210
#    Marine virus AFVG_250N01211
#    Marine virus AFVG_250N01212
#    Marine virus AFVG_250N01214
#    Marine virus AFVG_250N01215
#    Marine virus AFVG_250N01216
#    Marine virus AFVG_250N01219
#    Marine virus AFVG_250N01221
#    Marine virus AFVG_250N01223
#    Marine virus AFVG_250N01224
#    Marine virus AFVG_250N01226
#    Marine virus AFVG_250N01228
#    Marine virus AFVG_250N01231
#    Marine virus AFVG_250N01232
#    Marine virus AFVG_250N01233
#    Marine virus AFVG_250N01235
#    Marine virus AFVG_250N01236
#    Marine virus AFVG_250N01237
#    Marine virus AFVG_250N01238
#    Marine virus AFVG_250N01240
#    Marine virus AFVG_250N01241
#    Marine virus AFVG_250N01244
#    Marine virus AFVG_250N01245
#    Marine virus AFVG_250N01246
#    Marine virus AFVG_250N01247
#    Marine virus AFVG_250N01248
#    Marine virus AFVG_250N01250
#    Marine virus AFVG_250N01252
#    Marine virus AFVG_250N01256
#    Marine virus AFVG_250N01257
#    Marine virus AFVG_250N01258
#    Marine virus AFVG_250N01262
#    Marine virus AFVG_250N01263
#    Marine virus AFVG_250N01266
#    Marine virus AFVG_250N01268
#    Marine virus AFVG_250N01270
#    Marine virus AFVG_250N01273
#    Marine virus AFVG_250N01275
#    Marine virus AFVG_250N01276
#    Marine virus AFVG_250N01278
#    Marine virus AFVG_250N01279
#    Marine virus AFVG_250N01281
#    Marine virus AFVG_250N01283
#    Marine virus AFVG_250N01284
#    Marine virus AFVG_250N01285
#    Marine virus AFVG_250N01286
#    Marine virus AFVG_250N01287
#    Marine virus AFVG_250N01290
#    Marine virus AFVG_250N01291
#    Marine virus AFVG_250N01292
#    Marine virus AFVG_250N01293
#    Marine virus AFVG_250N01298
#    Marine virus AFVG_250N01299
#    Marine virus AFVG_250N01300
#    Marine virus AFVG_250N01302
#    Marine virus AFVG_250N01304
#    Marine virus AFVG_250N01306
#    Marine virus AFVG_250N01307
#    Marine virus AFVG_250N01309
#    Marine virus AFVG_250N01312
#    Marine virus AFVG_250N01313
#    Marine virus AFVG_250N01314
#    Marine virus AFVG_250N01317
#    Marine virus AFVG_250N01319
#    Marine virus AFVG_250N01323
#    Marine virus AFVG_250N01327
#    Marine virus AFVG_250N01328
#    Marine virus AFVG_250N01329
#    Marine virus AFVG_250N01333
#    Marine virus AFVG_250N01335
#    Marine virus AFVG_250N01336
#    Marine virus AFVG_250N01337
#    Marine virus AFVG_250N01339
#    Marine virus AFVG_250N01340
#    Marine virus AFVG_250N01341
#    Marine virus AFVG_250N01343
#    Marine virus AFVG_250N01346
#    Marine virus AFVG_250N01347
#    Marine virus AFVG_250N01349
#    Marine virus AFVG_250N01350
#    Marine virus AFVG_250N01351
#    Marine virus AFVG_250N01352
#    Marine virus AFVG_250N01353
#    Marine virus AFVG_250N01354
#    Marine virus AFVG_250N01355
#    Marine virus AFVG_250N01357
#    Marine virus AFVG_250N01358
#    Marine virus AFVG_250N01359
#    Marine virus AFVG_250N01360
#    Marine virus AFVG_250N01361
#    Marine virus AFVG_250N01363
#    Marine virus AFVG_250N01364
#    Marine virus AFVG_250N01365
#    Marine virus AFVG_250N01366
#    Marine virus AFVG_250N01367
#    Marine virus AFVG_250N01368
#    Marine virus AFVG_250N01372
#    Marine virus AFVG_250N01373
#    Marine virus AFVG_250N01375
#    Marine virus AFVG_250N01376
#    Marine virus AFVG_250N01377
#    Marine virus AFVG_250N01379
#    Marine virus AFVG_250N01380
#    Marine virus AFVG_250N01383
#    Marine virus AFVG_250N01384
#    Marine virus AFVG_250N01387
#    Marine virus AFVG_250N01389
#    Marine virus AFVG_250N01393
#    Marine virus AFVG_250N01395
#    Marine virus AFVG_250N01396
#    Marine virus AFVG_250N01399
#    Marine virus AFVG_250N01400
#    Marine virus AFVG_250N01401
#    Marine virus AFVG_250N01403
#    Marine virus AFVG_250N01408
#    Marine virus AFVG_250N01409
#    Marine virus AFVG_250N01413
#    Marine virus AFVG_250N01414
#    Marine virus AFVG_250N01415
#    Marine virus AFVG_250N01416
#    Marine virus AFVG_250N01417
#    Marine virus AFVG_250N01421
#    Marine virus AFVG_250N01427
#    Marine virus AFVG_250N01429
#    Marine virus AFVG_250N01430
#    Marine virus AFVG_250N01431
#    Marine virus AFVG_250N01434
#    Marine virus AFVG_250N01435
#    Marine virus AFVG_250N01438
#    Marine virus AFVG_250N01439
#  environmental samples
#   Boiling Springs Lake RNA-DNA hybrid virus
#   Breslo virus
#   Brinovirus
#   Calzovirus
#   Cilio virus
#   Eunivirus
#   Marine phage AC
#   Marine phage EC
#   Picalivirus D
#   Pyrobaculum genetic element 1
#   uncultured algal virus
#   uncultured archaeal virus
#   uncultured deep-sea hydrothermal vent virus
#   uncultured environmental isolates
#   uncultured human fecal virus
#   uncultured human saliva virus
#   uncultured marine RNA virus
#   uncultured marine virus
#   uncultured Mediterranean phage
#   uncultured mitochondrial RNA virus
#   uncultured Prochlorococcus cyanophage
#   uncultured Synechococcus cyanophage
#   uncultured virus
#   uncultured virus JFR_U1362B AD-236_A23
#   uncultured virus JFR_U1362B AD-236_C16
#   uncultured virus JFR_U1362B AD-236_F14
#   uncultured virus JFR_U1362B AD-236_F16
#   uncultured virus JFR_U1362B AD-236_F17
#   uncultured virus JFR_U1362B AD-236_M23
#   uncultured virus JFR_U1362B AD-236_N22
#   uncultured virus JFR_U1362B AD-236_P22

# %%
# Printa os itens como se fosse uma arvore usando uma biblioteca grafica
# importa a biblioteca grafica
import networkx as nx
import matplotlib.pyplot as plt

# cria um grafo
G = nx.Graph()

print(quantidade)

# Cria uma função para adicionar itens no grafo recursivamente e recebe um nivel maximo
def AdicionaItens(item, level, maxLevel, quantidadeDeFilhos):
    global G
    # verifica se o nivel é menor que o nivel maximo
    if level < maxLevel:
        # verifica se o item tem filhos
        if len(item.children) > 0:
            filhosIterados = 0
            # para cada filho do item
            for child in item.children:
                # verifica se o filho ja foi iterado
                if filhosIterados >= quantidadeDeFilhos:
                    break

                filhosIterados += 1

                # adiciona o filho no grafo
                G.add_node(child.name)

                # adiciona uma aresta entre o item e o filho
                G.add_edge(item.name, child.name)

                # chama a função novamente
                AdicionaItens(child, level + 1, maxLevel, quantidadeDeFilhos)
            

AdicionaItens(items[0], 0, 2, 30)

# Aumenta o tamanho do grafo
plt.figure(figsize=(10, 10))

# desenha o grafo que aceita muitos itens e niveis
nx.draw(G, with_labels=True, font_weight='bold')

# mostra o grafo
plt.show()
# Out:
# 12327

# %%
# Insere os dados na ontologia

# Verifica se o arquivo da ontologia existe
if os.path.exists("ontologia.owl"):
    # Remove o arquivo da ontologia
    os.remove("ontologia.owl")

# Cria a ontologia OntologiaVirus usando rdflib
onto = Graph()

# Cria o namespace da ontologia
onto.namespace_manager.bind("OntologiaVirus", URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#"))

# Cria a classes Host
onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#Host"), RDF.type, URIRef("http://www.w3.org/2002/07/owl#Class")))

def SerializaNome(nome):
    # Serializa o nome e tira caracteres especiais
    return nome.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "").replace("-", "").replace("'", "").replace(".", "").replace(",", "").replace(":", "").replace(";", "").replace("?", "").replace("!", "").replace(">", "").replace("<", "").replace("=", "").replace("+", "").replace("*", "").replace("&", "").replace("%", "").replace("$", "").replace("#", "").replace("@", "")
    
# Percorre os itens recursivamente se não for virus é uma classe, se for é um individuo, usa hierarquia de classes
def PercorreItens(item, parent):
    # Verifica se o item tem hosts, se tiver verifica se a classe já existe, se não existir cria a classe
    if len(item.hosts) > 0:
        for host in item.hosts:
            # Tira os espaços do começo e do fim do nome do host
            nomeHost = host.strip()
            nomeHost = SerializaNome(nomeHost)
            # Verifica se a classe já existe
            if onto.value(subject=None, predicate=URIRef("http://www.w3.org/2000/01/rdf-schema#label"), object=Literal(nomeHost)) == None:
                # Cria a classe
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)), 
                        RDF.type, URIRef("http://www.w3.org/2002/07/owl#Class")))
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)), 
                        URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(nomeHost)))
                # Cria a relação de subclasse com a classe Host
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)),
                            URIRef("http://www.w3.org/2000/01/rdf-schema#subClassOf"), URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#Host")))

    # Faz a mesma coisa para os viral hosts
    if len(item.viral_hosts) > 0:
        for host in item.viral_hosts:
            # Tira os espaços do começo e do fim do nome do host
            nomeHost = host.strip()
            nomeHost = SerializaNome(nomeHost)
            # Verifica se a classe já existe
            if onto.value(subject=None, predicate=URIRef("http://www.w3.org/2000/01/rdf-schema#label"), object=Literal(nomeHost)) == None:
                # Cria a classe
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)), 
                        RDF.type, URIRef("http://www.w3.org/2002/07/owl#Class")))
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)),
                        URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(nomeHost)))
                # Cria a relação de subclasse com a classe Host
                onto.add((URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(nomeHost)),
                        URIRef("http://www.w3.org/2000/01/rdf-schema#subClassOf"), URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#Host")))

    # verifica se o item é um virus
    if item.isVirus:
        # cria um individuo do item
        individuo = URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(item.name))
        # adiciona as propriedades do individuo
        onto.add((individuo, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(item.name)))
        onto.add((individuo, URIRef("http://www.w3.org/2000/01/rdf-schema#comment"), Literal(item.link)))

        # verifica se o item tem um pai
        if parent != "":
            # adiciona o individuo como instancia do pai
            onto.add((individuo, URIRef("http://www.w3.org/1999/02/22-rdf-syntax-ns#type"), parent))

    else:
        # cria uma Entidade classe do item
        classe = URIRef("http://www.semanticweb.org/deivis/ontologies/2023/5/OntologiaVirus#" + SerializaNome(item.name))
        # adiciona a classe na ontologia
        onto.add((classe, RDF.type, URIRef("http://www.w3.org/2002/07/owl#Class")))
        # verifica se o item tem um pai
        if parent != "":
            # adiciona a classe como subclasse do pai
            onto.add((classe, URIRef("http://www.w3.org/2000/01/rdf-schema#subClassOf"), parent))

        # adiciona as propriedades do item
        onto.add((classe, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(item.name)))
        onto.add((classe, URIRef("http://www.w3.org/2000/01/rdf-schema#comment"), Literal(item.link)))

        # verifica se o item tem filhos
        if len(item.children) > 0:
            # para cada filho do item
            for child in item.children:
                # chama a função novamente
                PercorreItens(child, classe)

# para cada item
for item in items:
    # chama a função para percorrer os itens, pai sendo Thing
    PercorreItens(item, URIRef("http://www.w3.org/2002/07/owl#Thing"))

# salva a ontologia, cria o arquivo
onto.serialize("ontologia.owl", format="xml")
# Out:
# <Graph identifier=Nf96ce563a4b546599fc26b0c89b0948a (<class 'rdflib.graph.Graph'>)>
