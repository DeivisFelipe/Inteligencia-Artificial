# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return np.e ** (-x / 10) * np.sin(np.pi * x)

def g(x):
    return x * np.e ** (-x / 3)

x = np.linspace(0, 10, 100)

plt.plot(x, f(x), label='f(x)')
plt.plot(x, g(x), label='g(x)')
